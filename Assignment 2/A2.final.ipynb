# %%
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

# %%
# THE DQN MODULE IMPLEMENTED USING PYTORCH FRAMEFORK
class DeepQNetwork(nn.Module):  
    def __init__(self, ALPHA, input_dims, fc1_dims, fc2_dims,         # initialises the DQN with the input dims.
                 n_actions):
        super(DeepQNetwork, self).__init__()
        self.input_dims = input_dims
        self.fc1_dims = fc1_dims
        self.fc2_dims = fc2_dims
        self.n_actions = n_actions
        self.fc1 = nn.Linear(*self.input_dims, self.fc1_dims)
        self.fc2 = nn.Linear(self.fc1_dims, self.fc2_dims)
        self.fc3 = nn.Linear(self.fc2_dims, self.n_actions)
        self.optimizer = optim.Adam(self.parameters(), lr=ALPHA)
        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cuda:1')
        self.to(self.device)

    def forward(self,state):                       # returns Q values corresponding to  # various actions available in state .
        x = F.relu(self.fc1(state.float()))
        x = F.relu(self.fc2(x))
        actions = self.fc3(x)
        return actions

# %%
class Agent(object):
    def __init__(self, gamma, epsilon, alpha, input_dims, batch_size, n_actions,   # initialises the agent
                 max_mem_size=100000, eps_end=0.01, eps_dec= 5e-1):
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_min = eps_end
        self.eps_dec = eps_dec
        self.alpha = alpha
        self.action_space = [i for i in range(n_actions)]
        self.n_actions = n_actions
        self.mem_size = max_mem_size
        self.batch_size = batch_size
        self.mem_cntr = 0   # stores the index of the element to remove and replace from the replay memory.
        self.Q_eval = DeepQNetwork(alpha, n_actions=self.n_actions,                 # the running Q network
                              input_dims=input_dims, fc1_dims=256, fc2_dims=256) 
        
        
        self.Q_train= DeepQNetwork(alpha, n_actions=self.n_actions, 
                                   input_dims=input_dims, fc1_dims=256, fc2_dims=256)  # the target Q network
        
        self.Q_train.load_state_dict(self.Q_eval.state_dict())   #using same weights for both 
        self.Q_train.eval()     # setting training net to eval mode
        
       
        self.state_memory = np.zeros((self.mem_size, *input_dims),dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_dims),dtype=np.float32)               # replay memory in form of for arrays
        self.action_memory = np.zeros(self.mem_size,
                                      dtype=np.int32)
        self.reward_memory = np.zeros(self.mem_size,dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)   # to check if the state is ending state or not
    
    def storeTransition(self, state, action, reward, state_, done):   # removes one element from replay memory and adds a new one 
        index = self.mem_cntr % self.mem_size   # to see which element to remove from the memory.
        self.state_memory[index] = state 
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.new_state_memory[index] = state_
        self.terminal_memory[index] = done
        self.mem_cntr += 1
        
    def chooseAction(self, observation):
        rand = np.random.random()
        if rand>self.epsilon:
            state=T.tensor([observation]).to(self.Q_eval.device)    # convert observation to tensor
            actions=self.Q_eval.forward(state) # Q values corresponding to different actions
            action=T.argmax(actions)
        else:
            action = np.random.choice(self.action_space)
        return action
    
    
    def learn(self):
            if self.mem_cntr<self.batch_size:
                return
            
            max_mem=min(self.mem_cntr,self.mem_size)
            batch = np.random.choice(max_mem, self.batch_size)
            batch_index=np.arange(self.batch_size,dtype=np.int32)
            
            state_batch = T.tensor(self.state_memory[batch]).to(self.Q_eval.device)
            new_state_batch = T.tensor(self.new_state_memory[batch]).to(self.Q_eval.device)
            reward_batch = T.tensor(self.reward_memory[batch]).to(self.Q_eval.device)
            terminal_batch = T.tensor(self.terminal_memory[batch]).to(self.Q_eval.device)
            action_batch= self.action_memory[batch]
            
            self.Q_eval.optimizer.zero_grad()
            
            q_eval = self.Q_eval.forward(state_batch)[batch_index,action_batch] # slicing to get the values 
                                                                                # corresponding to taken actions only.
            
            q_next = self.Q_train.forward(new_state_batch)
            q_next[terminal_batch]=0.0
            
            q_target= reward_batch+ self.gamma * T.max(q_next,dim=1)[0]   

            loss = self.Q_eval.loss(q_target, q_eval).to(self.Q_eval.device)
            loss.backward()
            self.Q_eval.optimizer.step()
            
            if self.epsilon > self.eps_min :
                self.epsilon-=self.eps_dec

# %%
import pandas as pd
df=pd.read_csv('GOOGl.csv')
df.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 2761  2019-12-20  1363.099976  1364.000000  1350.729980  1351.219971
# 2762  2019-12-23  1358.729980  1361.849976  1348.000000  1350.630005
# 2763  2019-12-24  1350.209961  1352.010010  1344.170044  1344.430054
# 2764  2019-12-26  1346.550049  1363.199951  1345.510010  1362.469971
# 2765  2019-12-27  1364.000000  1367.050049  1353.000000  1354.640015
#
#         Adj Close   Volume
# 2761  1351.219971  2504500
# 2762  1350.630005   996800
# 2763  1344.430054   673400
# 2764  1362.469971  1183100
# 2765  1354.640015  1160600

# %%
total=df.shape[0]
rel=df['Adj Close']
train_size= (int)(total*0.8)
train=rel[:train_size]
test=rel[train_size:]
test_vec=(list)(test)
train_vec=(list)(train)
print(type(test_vec[0]))
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(np.arange(train_size),train)
# Out:
# <class 'float'>

# %%
def upd_state(data,time,action,curr_stocks,n,tr_count,total_money,max_trans):
    state= np.array(data[time-n+1:time])
    worth_today= total_money+curr_stocks*data[time-1]
    if(action==0):
        curr_stocks+= ((total_money)/(max_trans-tr_count))/data[time-1]
        total_money-= ((total_money)/(max_trans-tr_count))
        tr_count+=1
    elif(action==1):
        total_money+=(data[time-1]*curr_stocks)
        curr_stocks=0
        tr_count=0
    worth_tomorrow=total_money+curr_stocks*data[time]
    if(data[time]>=data[time-1]):
        opt_action=0
    if(data[time]<data[time-1]):
        opt_action=1       
    state=np.append(state,curr_stocks)
    reward= (worth_tomorrow-worth_today)
    return (reward,state,curr_stocks,tr_count,total_money,opt_action)

# %%
num_episodes=50
profits=[]
data=train_vec
data_size=len(data)
state_size= 50
steps_upd_target=20  # steps after which target network should be updated
max_trans =50
total_money=10000
agent=Agent(gamma=0.95, epsilon=1, alpha=0.001, input_dims=[state_size], batch_size=32, n_actions=3,   # initialises the agent
                 max_mem_size=1000, eps_end=0.01, eps_dec= 2e-5)
for ep in np.arange(num_episodes):
    print("EPISODE",ep+1)
    time=state_size
    State=np.array(data[time-state_size+1:time],dtype=np.float32)
    State=np.append(State,0)
    curr_stocks= (float)(0)
    tr_count=0
    ep_reward=0
    total_money=10000
    dicti={0:"Buy",1:"Sell",2:"Hold"}
    while(time<data_size):
        action=agent.chooseAction(State)
        if(action==0 and tr_count<max_trans):
            action=0
        elif(action==0 and tr_count==max_trans):
            action=2
            
        reward,new_state,curr_stocks,tr_count,total_money,opt_action=upd_state(data,time,action,curr_stocks,state_size,tr_count,total_money,max_trans)
        agent.storeTransition(State, action, reward, new_state,0)
        agent.learn()
        State=new_state
        ep_reward+=reward
        if(time%steps_upd_target==0):
             agent.Q_train.load_state_dict(agent.Q_eval.state_dict())
        time+=1    
#         print(" TIME = ",time,"Action Taken = ",dicti[(int)(action)],"Action Expected =",dicti[opt_action],"Reward = ",reward)
    
    
    profits.append(ep_reward)
    net= total_money+curr_stocks*data[-1]
    print("Reward in Episode",ep+1,"=",ep_reward,"and net amount=",net,"epsilon = ",agent.epsilon)
# Out:
# EPISODE 1
# Reward in Episode 1 = 580.5411702606634 and net amount= 10580.541170260663 epsilon =  0.9573799999999574
# EPISODE 2
# Reward in Episode 2 = 205.0312014832234 and net amount= 10205.031201483223 epsilon =  0.9141399999999141
# EPISODE 3
# Reward in Episode 3 = 126.02428710815184 and net amount= 10126.024287108152 epsilon =  0.8708999999998709
# EPISODE 4
# Reward in Episode 4 = 325.3534529741519 and net amount= 10325.353452974152 epsilon =  0.8276599999998276
# EPISODE 5
# Reward in Episode 5 = 666.4955253669141 and net amount= 10666.495525366914 epsilon =  0.7844199999997844
# EPISODE 6
# Reward in Episode 6 = 751.098321217527 and net amount= 10751.098321217527 epsilon =  0.7411799999997412
# EPISODE 7
# Reward in Episode 7 = 647.9816213241083 and net amount= 10647.981621324108 epsilon =  0.6979399999996979
# EPISODE 8
# Reward in Episode 8 = 706.430180297395 and net amount= 10706.430180297395 epsilon =  0.6546999999996547
# EPISODE 9
# Reward in Episode 9 = 205.31602884114545 and net amount= 10205.316028841145 epsilon =  0.6114599999996114
# EPISODE 10
# Reward in Episode 10 = 277.5899508440798 and net amount= 10277.58995084408 epsilon =  0.5682199999995682
# EPISODE 11
# Reward in Episode 11 = 685.5461967887695 and net amount= 10685.54619678877 epsilon =  0.5249799999995249
# EPISODE 12
# Reward in Episode 12 = 1165.030955142067 and net amount= 11165.030955142067 epsilon =  0.4817399999994817
# EPISODE 13
# Reward in Episode 13 = 970.4029048114717 and net amount= 10970.402904811472 epsilon =  0.43849999999943845
# EPISODE 14
# Reward in Episode 14 = 1542.6442263494773 and net amount= 11542.644226349477 epsilon =  0.3952599999993952
# EPISODE 15
# Reward in Episode 15 = 2393.4023849615023 and net amount= 12393.402384961502 epsilon =  0.35201999999935196
# EPISODE 16
# Reward in Episode 16 = 3057.748064138721 and net amount= 13057.748064138721 epsilon =  0.3087799999993087
# EPISODE 17
# Reward in Episode 17 = 2412.1838708701252 and net amount= 12412.183870870125 epsilon =  0.2655399999992655
# EPISODE 18
# Reward in Episode 18 = 281.68841471791893 and net amount= 10281.688414717919 epsilon =  0.2222999999992607
# EPISODE 19
# Reward in Episode 19 = 591.8116106235102 and net amount= 10591.81161062351 epsilon =  0.17905999999927746
# EPISODE 20
# Reward in Episode 20 = 7132.161283570491 and net amount= 17132.16128357049 epsilon =  0.13581999999929423
# EPISODE 21
# Reward in Episode 21 = 3348.2777484775615 and net amount= 13348.277748477562 epsilon =  0.09257999999928848
# EPISODE 22
# Reward in Episode 22 = 651.4094992603677 and net amount= 10651.409499260368 epsilon =  0.049339999999279814
# EPISODE 23
# Reward in Episode 23 = 66.1484971610862 and net amount= 10066.148497161086 epsilon =  0.009999999999281417
# EPISODE 24
# Reward in Episode 24 = 88.8709125925925 and net amount= 10088.870912592593 epsilon =  0.009999999999281417
# EPISODE 25
# Reward in Episode 25 = 14018.940165903012 and net amount= 24018.94016590301 epsilon =  0.009999999999281417
# EPISODE 26
# Reward in Episode 26 = -62.866320612207346 and net amount= 9937.133679387793 epsilon =  0.009999999999281417
# EPISODE 27
# Reward in Episode 27 = 2263.550565672338 and net amount= 12263.550565672338 epsilon =  0.009999999999281417
# EPISODE 28
# Reward in Episode 28 = 32199.34042491203 and net amount= 42199.34042491203 epsilon =  0.009999999999281417
# EPISODE 29
# Reward in Episode 29 = 24881.74975655585 and net amount= 34881.74975655585 epsilon =  0.009999999999281417
# EPISODE 30
# Reward in Episode 30 = 4165.0168345548445 and net amount= 14165.016834554845 epsilon =  0.009999999999281417
# EPISODE 31
# Reward in Episode 31 = 1672.6100907591626 and net amount= 11672.610090759163 epsilon =  0.009999999999281417
# EPISODE 32
# Reward in Episode 32 = 7009.248267076651 and net amount= 17009.24826707665 epsilon =  0.009999999999281417
# EPISODE 33
# Reward in Episode 33 = 634.3112179325872 and net amount= 10634.311217932587 epsilon =  0.009999999999281417
# EPISODE 34
# Reward in Episode 34 = 245.41950414044186 and net amount= 10245.419504140442 epsilon =  0.009999999999281417
# EPISODE 35
# Reward in Episode 35 = 9764.030807316416 and net amount= 19764.030807316416 epsilon =  0.009999999999281417
# EPISODE 36
# Reward in Episode 36 = 621.2447744412457 and net amount= 10621.244774441246 epsilon =  0.009999999999281417
# EPISODE 37
# Reward in Episode 37 = 4409.463047968782 and net amount= 14409.463047968782 epsilon =  0.009999999999281417
# EPISODE 38
# Reward in Episode 38 = 471.87860193214874 and net amount= 10471.878601932149 epsilon =  0.009999999999281417
# EPISODE 39
# Reward in Episode 39 = 9633.100261422915 and net amount= 19633.100261422915 epsilon =  0.009999999999281417
# EPISODE 40
# Reward in Episode 40 = 3256.3148740841534 and net amount= 13256.314874084153 epsilon =  0.009999999999281417
# EPISODE 41
# Reward in Episode 41 = 15647.143932739364 and net amount= 25647.143932739364 epsilon =  0.009999999999281417
# EPISODE 42
# Reward in Episode 42 = 2821.4831784813614 and net amount= 12821.483178481361 epsilon =  0.009999999999281417
# EPISODE 43
# Reward in Episode 43 = 29805.083485563395 and net amount= 39805.083485563395 epsilon =  0.009999999999281417
# EPISODE 44
# Reward in Episode 44 = 4326.396200359297 and net amount= 14326.396200359297 epsilon =  0.009999999999281417
# EPISODE 45
# Reward in Episode 45 = 2596.341549092609 and net amount= 12596.341549092609 epsilon =  0.009999999999281417
# EPISODE 46
# Reward in Episode 46 = 7402.680881591128 and net amount= 17402.680881591128 epsilon =  0.009999999999281417
# EPISODE 47
# Reward in Episode 47 = 3039.5309604919876 and net amount= 13039.530960491988 epsilon =  0.009999999999281417
# EPISODE 48
# Reward in Episode 48 = 36281.29581406736 and net amount= 46281.29581406736 epsilon =  0.009999999999281417
# EPISODE 49
# Reward in Episode 49 = 24534.53593028982 and net amount= 34534.53593028982 epsilon =  0.009999999999281417
# EPISODE 50
# Reward in Episode 50 = 5084.568084355129 and net amount= 15084.568084355129 epsilon =  0.009999999999281417

# %%
data=test_vec
data_size=len(data)
data_size
print(len(test_vec))
state_size= 50
max_trans =50
total_money=10000
time=state_size
State=np.array(data[time-state_size+1:time],dtype=np.float32)
State=np.append(State,0)
curr_stocks= (float)(0)
tr_count=0
Reward=0
dicti={0:"Buy",1:"Sell",2:"Hold"}
while(time<data_size):
        action=agent.chooseAction(State)
        if(action==0 and tr_count<max_trans):
            action=0
        elif(action==0 and tr_count==max_trans):
            action=2
            
        reward,new_state,curr_stocks,tr_count,total_money,opt_action=upd_state(data,time,action,curr_stocks,state_size,tr_count,total_money,max_trans)
        print(" TIME = ",time,"Action Taken = ",dicti[(int)(action)],"Action Expected =",dicti[opt_action])
            
        State=new_state
        Reward+=reward
        time+=1    
#         print(Reward)
    
    
net= total_money+curr_stocks*data[-1]
print("Reward = ",Reward,"and net amount=",net)
# Out:
# 554
#  TIME =  50 Action Taken =  Buy Action Expected = Sell
#  TIME =  51 Action Taken =  Buy Action Expected = Sell
#  TIME =  52 Action Taken =  Buy Action Expected = Sell
#  TIME =  53 Action Taken =  Buy Action Expected = Buy
#  TIME =  54 Action Taken =  Buy Action Expected = Buy
#  TIME =  55 Action Taken =  Buy Action Expected = Buy
#  TIME =  56 Action Taken =  Buy Action Expected = Buy
#  TIME =  57 Action Taken =  Buy Action Expected = Buy
#  TIME =  58 Action Taken =  Buy Action Expected = Sell
#  TIME =  59 Action Taken =  Buy Action Expected = Sell
#  TIME =  60 Action Taken =  Buy Action Expected = Buy
#  TIME =  61 Action Taken =  Sell Action Expected = Buy
#  TIME =  62 Action Taken =  Buy Action Expected = Buy
#  TIME =  63 Action Taken =  Buy Action Expected = Buy
#  TIME =  64 Action Taken =  Buy Action Expected = Sell
#  TIME =  65 Action Taken =  Buy Action Expected = Buy
#  TIME =  66 Action Taken =  Buy Action Expected = Buy
#  TIME =  67 Action Taken =  Buy Action Expected = Buy
#  TIME =  68 Action Taken =  Buy Action Expected = Sell
#  TIME =  69 Action Taken =  Buy Action Expected = Buy
#  TIME =  70 Action Taken =  Buy Action Expected = Buy
#  TIME =  71 Action Taken =  Buy Action Expected = Sell
#  TIME =  72 Action Taken =  Buy Action Expected = Sell
#  TIME =  73 Action Taken =  Buy Action Expected = Buy
#  TIME =  74 Action Taken =  Buy Action Expected = Sell
#  TIME =  75 Action Taken =  Buy Action Expected = Sell
#  TIME =  76 Action Taken =  Buy Action Expected = Sell
#  TIME =  77 Action Taken =  Buy Action Expected = Buy
#  TIME =  78 Action Taken =  Buy Action Expected = Sell
#  TIME =  79 Action Taken =  Buy Action Expected = Sell
#  TIME =  80 Action Taken =  Buy Action Expected = Buy
#  TIME =  81 Action Taken =  Buy Action Expected = Buy
#  TIME =  82 Action Taken =  Buy Action Expected = Sell
#  TIME =  83 Action Taken =  Buy Action Expected = Buy
#  TIME =  84 Action Taken =  Buy Action Expected = Buy
#  TIME =  85 Action Taken =  Buy Action Expected = Buy
#  TIME =  86 Action Taken =  Buy Action Expected = Buy
#  TIME =  87 Action Taken =  Buy Action Expected = Buy
#  TIME =  88 Action Taken =  Buy Action Expected = Sell
#  TIME =  89 Action Taken =  Buy Action Expected = Buy
#  TIME =  90 Action Taken =  Buy Action Expected = Buy
#  TIME =  91 Action Taken =  Buy Action Expected = Sell
#  TIME =  92 Action Taken =  Buy Action Expected = Sell
#  TIME =  93 Action Taken =  Buy Action Expected = Sell
#  TIME =  94 Action Taken =  Buy Action Expected = Buy
#  TIME =  95 Action Taken =  Buy Action Expected = Buy
#  TIME =  96 Action Taken =  Buy Action Expected = Buy
#  TIME =  97 Action Taken =  Buy Action Expected = Buy
#  TIME =  98 Action Taken =  Buy Action Expected = Buy
#  TIME =  99 Action Taken =  Buy Action Expected = Buy
#  TIME =  100 Action Taken =  Buy Action Expected = Buy
#  TIME =  101 Action Taken =  Buy Action Expected = Sell
#  TIME =  102 Action Taken =  Buy Action Expected = Buy
#  TIME =  103 Action Taken =  Buy Action Expected = Buy
#  TIME =  104 Action Taken =  Buy Action Expected = Sell
#  TIME =  105 Action Taken =  Buy Action Expected = Sell
#  TIME =  106 Action Taken =  Buy Action Expected = Sell
#  TIME =  107 Action Taken =  Buy Action Expected = Sell
#  TIME =  108 Action Taken =  Buy Action Expected = Sell
#  TIME =  109 Action Taken =  Buy Action Expected = Sell
#  TIME =  110 Action Taken =  Buy Action Expected = Buy
#  TIME =  111 Action Taken =  Buy Action Expected = Sell
#  TIME =  112 Action Taken =  Hold Action Expected = Sell
#  TIME =  113 Action Taken =  Hold Action Expected = Buy
#  TIME =  114 Action Taken =  Hold Action Expected = Sell
#  TIME =  115 Action Taken =  Hold Action Expected = Buy
#  TIME =  116 Action Taken =  Hold Action Expected = Buy
#  TIME =  117 Action Taken =  Hold Action Expected = Buy
#  TIME =  118 Action Taken =  Hold Action Expected = Sell
#  TIME =  119 Action Taken =  Hold Action Expected = Buy
#  TIME =  120 Action Taken =  Hold Action Expected = Buy
#  TIME =  121 Action Taken =  Hold Action Expected = Sell
#  TIME =  122 Action Taken =  Hold Action Expected = Buy
#  TIME =  123 Action Taken =  Hold Action Expected = Sell
#  TIME =  124 Action Taken =  Hold Action Expected = Buy
#  TIME =  125 Action Taken =  Hold Action Expected = Buy
#  TIME =  126 Action Taken =  Hold Action Expected = Sell
#  TIME =  127 Action Taken =  Hold Action Expected = Buy
#  TIME =  128 Action Taken =  Hold Action Expected = Sell
#  TIME =  129 Action Taken =  Hold Action Expected = Sell
#  TIME =  130 Action Taken =  Hold Action Expected = Sell
#  TIME =  131 Action Taken =  Hold Action Expected = Buy
#  TIME =  132 Action Taken =  Hold Action Expected = Buy
#  TIME =  133 Action Taken =  Hold Action Expected = Sell
#  TIME =  134 Action Taken =  Hold Action Expected = Sell
#  TIME =  135 Action Taken =  Hold Action Expected = Buy
#  TIME =  136 Action Taken =  Hold Action Expected = Sell
#  TIME =  137 Action Taken =  Hold Action Expected = Buy
#  TIME =  138 Action Taken =  Hold Action Expected = Buy
#  TIME =  139 Action Taken =  Hold Action Expected = Buy
#  TIME =  140 Action Taken =  Hold Action Expected = Sell
#  TIME =  141 Action Taken =  Hold Action Expected = Buy
#  TIME =  142 Action Taken =  Hold Action Expected = Buy
#  TIME =  143 Action Taken =  Hold Action Expected = Sell
#  TIME =  144 Action Taken =  Hold Action Expected = Buy
#  TIME =  145 Action Taken =  Hold Action Expected = Sell
#  TIME =  146 Action Taken =  Hold Action Expected = Sell
#  TIME =  147 Action Taken =  Hold Action Expected = Sell
#  TIME =  148 Action Taken =  Hold Action Expected = Sell
#  TIME =  149 Action Taken =  Hold Action Expected = Buy
#  TIME =  150 Action Taken =  Hold Action Expected = Sell
#  TIME =  151 Action Taken =  Hold Action Expected = Buy
#  TIME =  152 Action Taken =  Sell Action Expected = Sell
#  TIME =  153 Action Taken =  Buy Action Expected = Sell
#  TIME =  154 Action Taken =  Buy Action Expected = Sell
#  TIME =  155 Action Taken =  Buy Action Expected = Buy
#  TIME =  156 Action Taken =  Buy Action Expected = Buy
#  TIME =  157 Action Taken =  Buy Action Expected = Buy
#  TIME =  158 Action Taken =  Buy Action Expected = Buy
#  TIME =  159 Action Taken =  Buy Action Expected = Sell
#  TIME =  160 Action Taken =  Buy Action Expected = Sell
#  TIME =  161 Action Taken =  Buy Action Expected = Sell
#  TIME =  162 Action Taken =  Buy Action Expected = Sell
#  TIME =  163 Action Taken =  Buy Action Expected = Buy
#  TIME =  164 Action Taken =  Buy Action Expected = Buy
#  TIME =  165 Action Taken =  Buy Action Expected = Sell
#  TIME =  166 Action Taken =  Buy Action Expected = Buy
#  TIME =  167 Action Taken =  Buy Action Expected = Sell
#  TIME =  168 Action Taken =  Buy Action Expected = Buy
#  TIME =  169 Action Taken =  Buy Action Expected = Sell
#  TIME =  170 Action Taken =  Buy Action Expected = Buy
#  TIME =  171 Action Taken =  Buy Action Expected = Sell
#  TIME =  172 Action Taken =  Buy Action Expected = Sell
#  TIME =  173 Action Taken =  Buy Action Expected = Sell
#  TIME =  174 Action Taken =  Buy Action Expected = Sell
#  TIME =  175 Action Taken =  Buy Action Expected = Sell
#  TIME =  176 Action Taken =  Buy Action Expected = Buy
#  TIME =  177 Action Taken =  Buy Action Expected = Buy
#  TIME =  178 Action Taken =  Buy Action Expected = Buy
#  TIME =  179 Action Taken =  Buy Action Expected = Sell
#  TIME =  180 Action Taken =  Buy Action Expected = Buy
#  TIME =  181 Action Taken =  Buy Action Expected = Buy
#  TIME =  182 Action Taken =  Buy Action Expected = Buy
#  TIME =  183 Action Taken =  Buy Action Expected = Sell
#  TIME =  184 Action Taken =  Buy Action Expected = Buy
#  TIME =  185 Action Taken =  Buy Action Expected = Buy
#  TIME =  186 Action Taken =  Buy Action Expected = Buy
#  TIME =  187 Action Taken =  Buy Action Expected = Sell
#  TIME =  188 Action Taken =  Buy Action Expected = Buy
#  TIME =  189 Action Taken =  Buy Action Expected = Sell
#  TIME =  190 Action Taken =  Buy Action Expected = Sell
#  TIME =  191 Action Taken =  Buy Action Expected = Sell
#  TIME =  192 Action Taken =  Buy Action Expected = Buy
#  TIME =  193 Action Taken =  Buy Action Expected = Buy
#  TIME =  194 Action Taken =  Buy Action Expected = Buy
#  TIME =  195 Action Taken =  Buy Action Expected = Buy
#  TIME =  196 Action Taken =  Buy Action Expected = Sell
#  TIME =  197 Action Taken =  Buy Action Expected = Sell
#  TIME =  198 Action Taken =  Buy Action Expected = Sell
#  TIME =  199 Action Taken =  Buy Action Expected = Buy
#  TIME =  200 Action Taken =  Buy Action Expected = Buy
#  TIME =  201 Action Taken =  Buy Action Expected = Sell
#  TIME =  202 Action Taken =  Buy Action Expected = Sell
#  TIME =  203 Action Taken =  Hold Action Expected = Buy
#  TIME =  204 Action Taken =  Hold Action Expected = Buy
#  TIME =  205 Action Taken =  Hold Action Expected = Buy
#  TIME =  206 Action Taken =  Hold Action Expected = Sell
#  TIME =  207 Action Taken =  Hold Action Expected = Sell
#  TIME =  208 Action Taken =  Hold Action Expected = Buy
#  TIME =  209 Action Taken =  Hold Action Expected = Sell
#  TIME =  210 Action Taken =  Hold Action Expected = Sell
#  TIME =  211 Action Taken =  Hold Action Expected = Sell
#  TIME =  212 Action Taken =  Hold Action Expected = Buy
#  TIME =  213 Action Taken =  Hold Action Expected = Sell
#  TIME =  214 Action Taken =  Hold Action Expected = Buy
#  TIME =  215 Action Taken =  Hold Action Expected = Sell
#  TIME =  216 Action Taken =  Hold Action Expected = Buy
#  TIME =  217 Action Taken =  Hold Action Expected = Buy
#  TIME =  218 Action Taken =  Hold Action Expected = Sell
#  TIME =  219 Action Taken =  Hold Action Expected = Buy
#  TIME =  220 Action Taken =  Hold Action Expected = Sell
#  TIME =  221 Action Taken =  Hold Action Expected = Sell
#  TIME =  222 Action Taken =  Hold Action Expected = Sell
#  TIME =  223 Action Taken =  Hold Action Expected = Sell
#  TIME =  224 Action Taken =  Hold Action Expected = Sell
#  TIME =  225 Action Taken =  Hold Action Expected = Sell
#  TIME =  226 Action Taken =  Hold Action Expected = Sell
#  TIME =  227 Action Taken =  Hold Action Expected = Buy
#  TIME =  228 Action Taken =  Hold Action Expected = Sell
#  TIME =  229 Action Taken =  Hold Action Expected = Buy
#  TIME =  230 Action Taken =  Hold Action Expected = Sell
#  TIME =  231 Action Taken =  Hold Action Expected = Sell
#  TIME =  232 Action Taken =  Hold Action Expected = Buy
#  TIME =  233 Action Taken =  Hold Action Expected = Buy
#  TIME =  234 Action Taken =  Hold Action Expected = Buy
#  TIME =  235 Action Taken =  Hold Action Expected = Sell
#  TIME =  236 Action Taken =  Hold Action Expected = Buy
#  TIME =  237 Action Taken =  Hold Action Expected = Buy
#  TIME =  238 Action Taken =  Hold Action Expected = Buy
#  TIME =  239 Action Taken =  Hold Action Expected = Buy
#  TIME =  240 Action Taken =  Hold Action Expected = Sell
#  TIME =  241 Action Taken =  Hold Action Expected = Buy
#  TIME =  242 Action Taken =  Hold Action Expected = Sell
#  TIME =  243 Action Taken =  Hold Action Expected = Buy
#  TIME =  244 Action Taken =  Hold Action Expected = Sell
#  TIME =  245 Action Taken =  Hold Action Expected = Sell
#  TIME =  246 Action Taken =  Hold Action Expected = Sell
#  TIME =  247 Action Taken =  Hold Action Expected = Sell
#  TIME =  248 Action Taken =  Hold Action Expected = Sell
#  TIME =  249 Action Taken =  Hold Action Expected = Sell
#  TIME =  250 Action Taken =  Hold Action Expected = Buy
#  TIME =  251 Action Taken =  Hold Action Expected = Sell
#  TIME =  252 Action Taken =  Hold Action Expected = Buy
#  TIME =  253 Action Taken =  Hold Action Expected = Sell
#  TIME =  254 Action Taken =  Hold Action Expected = Sell
#  TIME =  255 Action Taken =  Hold Action Expected = Buy
#  TIME =  256 Action Taken =  Hold Action Expected = Buy
#  TIME =  257 Action Taken =  Hold Action Expected = Buy
#  TIME =  258 Action Taken =  Hold Action Expected = Sell
#  TIME =  259 Action Taken =  Hold Action Expected = Buy
#  TIME =  260 Action Taken =  Hold Action Expected = Sell
#  TIME =  261 Action Taken =  Hold Action Expected = Sell
#  TIME =  262 Action Taken =  Hold Action Expected = Buy
#  TIME =  263 Action Taken =  Hold Action Expected = Buy
#  TIME =  264 Action Taken =  Hold Action Expected = Sell
#  TIME =  265 Action Taken =  Hold Action Expected = Sell
#  TIME =  266 Action Taken =  Hold Action Expected = Sell
#  TIME =  267 Action Taken =  Hold Action Expected = Buy
#  TIME =  268 Action Taken =  Hold Action Expected = Buy
#  TIME =  269 Action Taken =  Hold Action Expected = Sell
#  TIME =  270 Action Taken =  Hold Action Expected = Sell
#  TIME =  271 Action Taken =  Hold Action Expected = Sell
#  TIME =  272 Action Taken =  Hold Action Expected = Sell
#  TIME =  273 Action Taken =  Hold Action Expected = Buy
#  TIME =  274 Action Taken =  Hold Action Expected = Buy
#  TIME =  275 Action Taken =  Hold Action Expected = Sell
#  TIME =  276 Action Taken =  Hold Action Expected = Sell
#  TIME =  277 Action Taken =  Hold Action Expected = Buy
#  TIME =  278 Action Taken =  Hold Action Expected = Buy
#  TIME =  279 Action Taken =  Hold Action Expected = Sell
#  TIME =  280 Action Taken =  Hold Action Expected = Buy
#  TIME =  281 Action Taken =  Hold Action Expected = Sell
#  TIME =  282 Action Taken =  Hold Action Expected = Buy
#  TIME =  283 Action Taken =  Hold Action Expected = Buy
#  TIME =  284 Action Taken =  Hold Action Expected = Buy
#  TIME =  285 Action Taken =  Hold Action Expected = Buy
#  TIME =  286 Action Taken =  Hold Action Expected = Sell
#  TIME =  287 Action Taken =  Hold Action Expected = Buy
#  TIME =  288 Action Taken =  Hold Action Expected = Sell
#  TIME =  289 Action Taken =  Hold Action Expected = Buy
#  TIME =  290 Action Taken =  Hold Action Expected = Buy
#  TIME =  291 Action Taken =  Hold Action Expected = Buy
#  TIME =  292 Action Taken =  Hold Action Expected = Sell
#  TIME =  293 Action Taken =  Hold Action Expected = Sell
#  TIME =  294 Action Taken =  Hold Action Expected = Sell
#  TIME =  295 Action Taken =  Hold Action Expected = Buy
#  TIME =  296 Action Taken =  Hold Action Expected = Sell
#  TIME =  297 Action Taken =  Hold Action Expected = Sell
#  TIME =  298 Action Taken =  Hold Action Expected = Sell
#  TIME =  299 Action Taken =  Hold Action Expected = Sell
#  TIME =  300 Action Taken =  Hold Action Expected = Buy
#  TIME =  301 Action Taken =  Hold Action Expected = Buy
#  TIME =  302 Action Taken =  Hold Action Expected = Sell
#  TIME =  303 Action Taken =  Hold Action Expected = Sell
#  TIME =  304 Action Taken =  Hold Action Expected = Buy
#  TIME =  305 Action Taken =  Hold Action Expected = Sell
#  TIME =  306 Action Taken =  Hold Action Expected = Buy
#  TIME =  307 Action Taken =  Hold Action Expected = Sell
#  TIME =  308 Action Taken =  Hold Action Expected = Buy
#  TIME =  309 Action Taken =  Hold Action Expected = Sell
#  TIME =  310 Action Taken =  Hold Action Expected = Sell
#  TIME =  311 Action Taken =  Hold Action Expected = Sell
#  TIME =  312 Action Taken =  Hold Action Expected = Sell
#  TIME =  313 Action Taken =  Hold Action Expected = Buy
#  TIME =  314 Action Taken =  Hold Action Expected = Buy
#  TIME =  315 Action Taken =  Hold Action Expected = Buy
#  TIME =  316 Action Taken =  Hold Action Expected = Buy
#  TIME =  317 Action Taken =  Hold Action Expected = Sell
#  TIME =  318 Action Taken =  Hold Action Expected = Buy
#  TIME =  319 Action Taken =  Hold Action Expected = Sell
#  TIME =  320 Action Taken =  Hold Action Expected = Buy
#  TIME =  321 Action Taken =  Hold Action Expected = Sell
#  TIME =  322 Action Taken =  Hold Action Expected = Sell
#  TIME =  323 Action Taken =  Hold Action Expected = Buy
#  TIME =  324 Action Taken =  Hold Action Expected = Buy
#  TIME =  325 Action Taken =  Hold Action Expected = Sell
#  TIME =  326 Action Taken =  Hold Action Expected = Buy
#  TIME =  327 Action Taken =  Hold Action Expected = Buy
#  TIME =  328 Action Taken =  Hold Action Expected = Sell
#  TIME =  329 Action Taken =  Hold Action Expected = Sell
#  TIME =  330 Action Taken =  Hold Action Expected = Sell
#  TIME =  331 Action Taken =  Hold Action Expected = Sell
#  TIME =  332 Action Taken =  Hold Action Expected = Buy
#  TIME =  333 Action Taken =  Hold Action Expected = Buy
#  TIME =  334 Action Taken =  Hold Action Expected = Buy
#  TIME =  335 Action Taken =  Hold Action Expected = Sell
#  TIME =  336 Action Taken =  Hold Action Expected = Buy
#  TIME =  337 Action Taken =  Hold Action Expected = Sell
#  TIME =  338 Action Taken =  Hold Action Expected = Sell
#  TIME =  339 Action Taken =  Hold Action Expected = Buy
#  TIME =  340 Action Taken =  Hold Action Expected = Buy
#  TIME =  341 Action Taken =  Hold Action Expected = Buy
#  TIME =  342 Action Taken =  Hold Action Expected = Buy
#  TIME =  343 Action Taken =  Hold Action Expected = Buy
#  TIME =  344 Action Taken =  Hold Action Expected = Buy
#  TIME =  345 Action Taken =  Sell Action Expected = Buy
#  TIME =  346 Action Taken =  Buy Action Expected = Buy
#  TIME =  347 Action Taken =  Buy Action Expected = Sell
#  TIME =  348 Action Taken =  Buy Action Expected = Sell
#  TIME =  349 Action Taken =  Buy Action Expected = Sell
#  TIME =  350 Action Taken =  Buy Action Expected = Buy
#  TIME =  351 Action Taken =  Buy Action Expected = Buy
#  TIME =  352 Action Taken =  Buy Action Expected = Buy
#  TIME =  353 Action Taken =  Buy Action Expected = Sell
#  TIME =  354 Action Taken =  Buy Action Expected = Sell
#  TIME =  355 Action Taken =  Buy Action Expected = Sell
#  TIME =  356 Action Taken =  Buy Action Expected = Buy
#  TIME =  357 Action Taken =  Buy Action Expected = Buy
#  TIME =  358 Action Taken =  Buy Action Expected = Buy
#  TIME =  359 Action Taken =  Buy Action Expected = Sell
#  TIME =  360 Action Taken =  Buy Action Expected = Sell
#  TIME =  361 Action Taken =  Buy Action Expected = Sell
#  TIME =  362 Action Taken =  Buy Action Expected = Sell
#  TIME =  363 Action Taken =  Buy Action Expected = Sell
#  TIME =  364 Action Taken =  Buy Action Expected = Buy
#  TIME =  365 Action Taken =  Buy Action Expected = Buy
#  TIME =  366 Action Taken =  Buy Action Expected = Buy
#  TIME =  367 Action Taken =  Buy Action Expected = Buy
#  TIME =  368 Action Taken =  Buy Action Expected = Buy
#  TIME =  369 Action Taken =  Buy Action Expected = Sell
#  TIME =  370 Action Taken =  Buy Action Expected = Sell
#  TIME =  371 Action Taken =  Buy Action Expected = Sell
#  TIME =  372 Action Taken =  Buy Action Expected = Buy
#  TIME =  373 Action Taken =  Buy Action Expected = Buy
#  TIME =  374 Action Taken =  Buy Action Expected = Buy
#  TIME =  375 Action Taken =  Buy Action Expected = Buy
#  TIME =  376 Action Taken =  Buy Action Expected = Buy
#  TIME =  377 Action Taken =  Buy Action Expected = Buy
#  TIME =  378 Action Taken =  Buy Action Expected = Buy
#  TIME =  379 Action Taken =  Buy Action Expected = Buy
#  TIME =  380 Action Taken =  Buy Action Expected = Buy
#  TIME =  381 Action Taken =  Buy Action Expected = Sell
#  TIME =  382 Action Taken =  Buy Action Expected = Buy
#  TIME =  383 Action Taken =  Buy Action Expected = Buy
#  TIME =  384 Action Taken =  Buy Action Expected = Buy
#  TIME =  385 Action Taken =  Buy Action Expected = Sell
#  TIME =  386 Action Taken =  Buy Action Expected = Sell
#  TIME =  387 Action Taken =  Buy Action Expected = Sell
#  TIME =  388 Action Taken =  Buy Action Expected = Buy
#  TIME =  389 Action Taken =  Buy Action Expected = Buy
#  TIME =  390 Action Taken =  Buy Action Expected = Sell
#  TIME =  391 Action Taken =  Buy Action Expected = Sell
#  TIME =  392 Action Taken =  Buy Action Expected = Sell
#  TIME =  393 Action Taken =  Buy Action Expected = Sell
#  TIME =  394 Action Taken =  Buy Action Expected = Sell
#  TIME =  395 Action Taken =  Buy Action Expected = Sell
#  TIME =  396 Action Taken =  Hold Action Expected = Buy
#  TIME =  397 Action Taken =  Hold Action Expected = Buy
#  TIME =  398 Action Taken =  Hold Action Expected = Sell
#  TIME =  399 Action Taken =  Hold Action Expected = Sell
#  TIME =  400 Action Taken =  Hold Action Expected = Buy
#  TIME =  401 Action Taken =  Hold Action Expected = Buy
#  TIME =  402 Action Taken =  Hold Action Expected = Sell
#  TIME =  403 Action Taken =  Hold Action Expected = Sell
#  TIME =  404 Action Taken =  Hold Action Expected = Buy
#  TIME =  405 Action Taken =  Hold Action Expected = Sell
#  TIME =  406 Action Taken =  Hold Action Expected = Buy
#  TIME =  407 Action Taken =  Hold Action Expected = Sell
#  TIME =  408 Action Taken =  Hold Action Expected = Sell
#  TIME =  409 Action Taken =  Hold Action Expected = Buy
#  TIME =  410 Action Taken =  Hold Action Expected = Sell
#  TIME =  411 Action Taken =  Hold Action Expected = Buy
#  TIME =  412 Action Taken =  Hold Action Expected = Buy
#  TIME =  413 Action Taken =  Hold Action Expected = Buy
#  TIME =  414 Action Taken =  Hold Action Expected = Sell
#  TIME =  415 Action Taken =  Hold Action Expected = Sell
#  TIME =  416 Action Taken =  Hold Action Expected = Buy
#  TIME =  417 Action Taken =  Hold Action Expected = Sell
#  TIME =  418 Action Taken =  Hold Action Expected = Buy
#  TIME =  419 Action Taken =  Hold Action Expected = Buy
#  TIME =  420 Action Taken =  Hold Action Expected = Sell
#  TIME =  421 Action Taken =  Hold Action Expected = Buy
#  TIME =  422 Action Taken =  Hold Action Expected = Buy
#  TIME =  423 Action Taken =  Hold Action Expected = Sell
#  TIME =  424 Action Taken =  Hold Action Expected = Sell
#  TIME =  425 Action Taken =  Hold Action Expected = Sell
#  TIME =  426 Action Taken =  Hold Action Expected = Sell
#  TIME =  427 Action Taken =  Hold Action Expected = Buy
#  TIME =  428 Action Taken =  Hold Action Expected = Buy
#  TIME =  429 Action Taken =  Hold Action Expected = Buy
#  TIME =  430 Action Taken =  Hold Action Expected = Buy
#  TIME =  431 Action Taken =  Hold Action Expected = Buy
#  TIME =  432 Action Taken =  Hold Action Expected = Sell
#  TIME =  433 Action Taken =  Hold Action Expected = Buy
#  TIME =  434 Action Taken =  Hold Action Expected = Buy
#  TIME =  435 Action Taken =  Hold Action Expected = Buy
#  TIME =  436 Action Taken =  Hold Action Expected = Buy
#  TIME =  437 Action Taken =  Hold Action Expected = Buy
#  TIME =  438 Action Taken =  Hold Action Expected = Buy
#  TIME =  439 Action Taken =  Hold Action Expected = Sell
#  TIME =  440 Action Taken =  Hold Action Expected = Buy
#  TIME =  441 Action Taken =  Hold Action Expected = Sell
#  TIME =  442 Action Taken =  Hold Action Expected = Buy
#  TIME =  443 Action Taken =  Hold Action Expected = Buy
#  TIME =  444 Action Taken =  Hold Action Expected = Sell
#  TIME =  445 Action Taken =  Hold Action Expected = Sell
#  TIME =  446 Action Taken =  Hold Action Expected = Buy
#  TIME =  447 Action Taken =  Hold Action Expected = Sell
#  TIME =  448 Action Taken =  Hold Action Expected = Sell
#  TIME =  449 Action Taken =  Hold Action Expected = Sell
#  TIME =  450 Action Taken =  Hold Action Expected = Sell
#  TIME =  451 Action Taken =  Hold Action Expected = Sell
#  TIME =  452 Action Taken =  Hold Action Expected = Sell
#  TIME =  453 Action Taken =  Hold Action Expected = Buy
#  TIME =  454 Action Taken =  Hold Action Expected = Buy
#  TIME =  455 Action Taken =  Hold Action Expected = Buy
#  TIME =  456 Action Taken =  Hold Action Expected = Sell
#  TIME =  457 Action Taken =  Hold Action Expected = Sell
#  TIME =  458 Action Taken =  Hold Action Expected = Buy
#  TIME =  459 Action Taken =  Hold Action Expected = Sell
#  TIME =  460 Action Taken =  Hold Action Expected = Buy
#  TIME =  461 Action Taken =  Hold Action Expected = Buy
#  TIME =  462 Action Taken =  Hold Action Expected = Buy
#  TIME =  463 Action Taken =  Hold Action Expected = Sell
#  TIME =  464 Action Taken =  Hold Action Expected = Buy
#  TIME =  465 Action Taken =  Hold Action Expected = Sell
#  TIME =  466 Action Taken =  Hold Action Expected = Sell
#  TIME =  467 Action Taken =  Hold Action Expected = Buy
#  TIME =  468 Action Taken =  Hold Action Expected = Sell
#  TIME =  469 Action Taken =  Hold Action Expected = Buy
#  TIME =  470 Action Taken =  Hold Action Expected = Buy
#  TIME =  471 Action Taken =  Hold Action Expected = Sell
#  TIME =  472 Action Taken =  Hold Action Expected = Sell
#  TIME =  473 Action Taken =  Hold Action Expected = Buy
#  TIME =  474 Action Taken =  Hold Action Expected = Buy
#  TIME =  475 Action Taken =  Hold Action Expected = Sell
#  TIME =  476 Action Taken =  Hold Action Expected = Sell
#  TIME =  477 Action Taken =  Hold Action Expected = Buy
#  TIME =  478 Action Taken =  Hold Action Expected = Buy
#  TIME =  479 Action Taken =  Hold Action Expected = Buy
#  TIME =  480 Action Taken =  Hold Action Expected = Buy
#  TIME =  481 Action Taken =  Hold Action Expected = Sell
#  TIME =  482 Action Taken =  Hold Action Expected = Sell
#  TIME =  483 Action Taken =  Hold Action Expected = Buy
#  TIME =  484 Action Taken =  Hold Action Expected = Buy
#  TIME =  485 Action Taken =  Hold Action Expected = Sell
#  TIME =  486 Action Taken =  Hold Action Expected = Buy
#  TIME =  487 Action Taken =  Hold Action Expected = Sell
#  TIME =  488 Action Taken =  Hold Action Expected = Buy
#  TIME =  489 Action Taken =  Hold Action Expected = Sell
#  TIME =  490 Action Taken =  Hold Action Expected = Sell
#  TIME =  491 Action Taken =  Hold Action Expected = Sell
#  TIME =  492 Action Taken =  Hold Action Expected = Sell
#  TIME =  493 Action Taken =  Hold Action Expected = Sell
#  TIME =  494 Action Taken =  Hold Action Expected = Buy
#  TIME =  495 Action Taken =  Hold Action Expected = Buy
#  TIME =  496 Action Taken =  Hold Action Expected = Sell
#  TIME =  497 Action Taken =  Hold Action Expected = Sell
#  TIME =  498 Action Taken =  Hold Action Expected = Buy
#  TIME =  499 Action Taken =  Hold Action Expected = Buy
#  TIME =  500 Action Taken =  Hold Action Expected = Buy
#  TIME =  501 Action Taken =  Hold Action Expected = Buy
#  TIME =  502 Action Taken =  Hold Action Expected = Buy
#  TIME =  503 Action Taken =  Hold Action Expected = Buy
#  TIME =  504 Action Taken =  Hold Action Expected = Buy
#  TIME =  505 Action Taken =  Hold Action Expected = Sell
#  TIME =  506 Action Taken =  Hold Action Expected = Sell
#  TIME =  507 Action Taken =  Hold Action Expected = Sell
#  TIME =  508 Action Taken =  Hold Action Expected = Buy
#  TIME =  509 Action Taken =  Hold Action Expected = Buy
#  TIME =  510 Action Taken =  Hold Action Expected = Buy
#  TIME =  511 Action Taken =  Hold Action Expected = Buy
#  TIME =  512 Action Taken =  Hold Action Expected = Sell
#  TIME =  513 Action Taken =  Hold Action Expected = Buy
#  TIME =  514 Action Taken =  Hold Action Expected = Sell
#  TIME =  515 Action Taken =  Hold Action Expected = Buy
#  TIME =  516 Action Taken =  Hold Action Expected = Buy
#  TIME =  517 Action Taken =  Hold Action Expected = Buy
#  TIME =  518 Action Taken =  Hold Action Expected = Sell
#  TIME =  519 Action Taken =  Hold Action Expected = Buy
#  TIME =  520 Action Taken =  Hold Action Expected = Buy
#  TIME =  521 Action Taken =  Hold Action Expected = Sell
#  TIME =  522 Action Taken =  Hold Action Expected = Sell
#  TIME =  523 Action Taken =  Hold Action Expected = Sell
#  TIME =  524 Action Taken =  Hold Action Expected = Buy
#  TIME =  525 Action Taken =  Hold Action Expected = Buy
#  TIME =  526 Action Taken =  Hold Action Expected = Sell
#  TIME =  527 Action Taken =  Hold Action Expected = Sell
#  TIME =  528 Action Taken =  Hold Action Expected = Sell
#  TIME =  529 Action Taken =  Hold Action Expected = Sell
#  TIME =  530 Action Taken =  Hold Action Expected = Sell
#  TIME =  531 Action Taken =  Hold Action Expected = Buy
#  TIME =  532 Action Taken =  Hold Action Expected = Buy
#  TIME =  533 Action Taken =  Hold Action Expected = Sell
#  TIME =  534 Action Taken =  Hold Action Expected = Sell
#  TIME =  535 Action Taken =  Hold Action Expected = Sell
#  TIME =  536 Action Taken =  Hold Action Expected = Buy
#  TIME =  537 Action Taken =  Hold Action Expected = Buy
#  TIME =  538 Action Taken =  Hold Action Expected = Buy
#  TIME =  539 Action Taken =  Hold Action Expected = Buy
#  TIME =  540 Action Taken =  Hold Action Expected = Buy
#  TIME =  541 Action Taken =  Hold Action Expected = Sell
#  TIME =  542 Action Taken =  Hold Action Expected = Buy
#  TIME =  543 Action Taken =  Hold Action Expected = Buy
#  TIME =  544 Action Taken =  Hold Action Expected = Sell
#  TIME =  545 Action Taken =  Hold Action Expected = Buy
#  TIME =  546 Action Taken =  Hold Action Expected = Sell
#  TIME =  547 Action Taken =  Hold Action Expected = Sell
#  TIME =  548 Action Taken =  Hold Action Expected = Buy
#  TIME =  549 Action Taken =  Hold Action Expected = Sell
#  TIME =  550 Action Taken =  Hold Action Expected = Sell
#  TIME =  551 Action Taken =  Hold Action Expected = Sell
#  TIME =  552 Action Taken =  Hold Action Expected = Buy
#  TIME =  553 Action Taken =  Hold Action Expected = Sell
# Reward =  873.3157257270577 and net amount= 10873.315725727058

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(np.arange(data_size),data)
